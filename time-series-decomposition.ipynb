# %% [markdown]
# <a href="https://colab.research.google.com/github/swethag04/ml-projects/blob/main/time-series-decomposition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.seasonal import STL

import statsmodels.api as sm
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
sunspots = sm.datasets.sunspots.load_pandas()
air = pd.read_csv('sample_data/AirPassengers.csv')

# %%
sunspots_df = sunspots.data
sunspots_df.head(5)
# Out:
#      YEAR  SUNACTIVITY
# 0  1700.0          5.0
# 1  1701.0         11.0
# 2  1702.0         16.0
# 3  1703.0         23.0
# 4  1704.0         36.0

# %%
sunspots_df.dtypes
# Out:
# YEAR           float64
# SUNACTIVITY    float64
# dtype: object

# %%
sunspots_df.index = pd.date_range(start='1700-01-01',
                                 periods= len(sunspots_df), freq='A')
sunspots_df.head()
# Out:
#               YEAR  SUNACTIVITY
# 1700-12-31  1700.0          5.0
# 1701-12-31  1701.0         11.0
# 1702-12-31  1702.0         16.0
# 1703-12-31  1703.0         23.0
# 1704-12-31  1704.0         36.0

# %%
sunspots_df = sunspots_df.drop(columns=['YEAR'])
sunspots_df.head(0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-c345725b2bd6> in <cell line: 1>()
# ----> 1 sunspots_df = sunspots_df.drop(columns=['YEAR'])
#       2 sunspots_df.head(0)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# ...

# %%
sunspots_df.plot(figsize=(10,5))
# Out:
# <Axes: >

# %%
decompose = seasonal_decompose(sunspots_df, model='additive', period=11)
decompose.plot()
plt.figure(figsize=(10,5))
plt.show()

# %%
sunspots_df.head()
# Out:
#             SUNACTIVITY
# 1700-12-31          5.0
# 1701-12-31         11.0
# 1702-12-31         16.0
# 1703-12-31         23.0
# 1704-12-31         36.0

# %%
air.head(5)
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
air['Month'] = pd.to_datetime(air['Month'])
air.set_index('Month', inplace=True)

# %%
air.head(5)
# Out:
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121

# %%
air.shape
# Out:
# (144, 1)

# %%
air.plot(figsize=(10,5))
# Out:
# <Axes: xlabel='Month'>

# %%
air_decompose = seasonal_decompose(air, model='multiplicative', period=12)
air_decompose.plot()
plt.figure(figsize=(10,5))
plt.show()
